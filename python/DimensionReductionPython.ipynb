# %%
from scipy import misc as im
path = '../data/lfw/Aaron_Eckhart/Aaron_Eckhart_0001.jpg'
ae = im.imread(path)
from matplotlib import pyplot as plt
plt.imshow(ae)
plt.show()

# %%
path = 'Aaron_Eckhart_0001.jpg'
plt.imshow(im.imread(path), cmap=plt.get_cmap('gray'))
plt.show()

# %%
import numpy as np
pcs = np.loadtxt("pc.csv", delimiter=",")
print(pcs.shape)
# Out:
# (2500, 10)

# %%
def plot_gallery(images, h, w, n_row=2, n_col=5):
    from matplotlib import pyplot as plt
    plt.clf()
    plt.figure(figsize=(1.8 * n_col, 2.4 * n_row))
    plt.subplots_adjust(bottom=0, left=0.01, right=0.99, top=0.90, hspace=0.35)
    for i in range(n_row * n_col):
        plt.subplot(n_row, n_col, i + 1)
        plt.imshow(images[:, i].reshape((h, w)), cmap=plt.get_cmap('gray'))
        plt.title("Eigenface %d" % (i + 1), size = 12)
        plt.xticks(())
        plt.yticks(())
    plt.show()
plot_gallery(pcs, 50, 50)

# %%
s = np.loadtxt("s.csv", delimiter=",")
print(s.shape)
from matplotlib import pyplot as plt
plt.plot(s)
plt.show()
plt.clf()
plt.plot(np.cumsum(s))
plt.yscale('log')
plt.show()
# Out:
# (300,)
